# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

#loaded required libraries

# %%
train = pd.read_csv('D:\Flip Robo\Project-Housing_splitted/train.csv')
test = pd.read_csv('D:\Flip Robo\Project-Housing_splitted/test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   Alley          14 non-null     object
#  7   LotShape       292 non-null    object
#  8   LandContour    292 non-null    object
#  9   Utilities      292 non-null    object
#  10  LotConfig      292 non-null    object
#  11  LandSlope      292 non-null    object
#  12  Neighborhood   292 non-null    object
#  13  Condition1     292 non-null    object
#  14  Condition2     292 non-null    object
#  15  BldgType       292 non-null    object
#  16  HouseStyle     292 non-null    object
# ...

# %%
print(train.isnull().values.any())
print(train.isnull().sum())
pd.set_option('display.max_rows', train.shape[0]+1)
# Out:
# True
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       214
# LotArea             0
# Street              0
# Alley            1091
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          7
# MasVnrArea          7
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           30
# BsmtCond           30
# BsmtExposure       31
# BsmtFinType1       30
# BsmtFinSF1          0
# BsmtFinType2       31
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
print(test.isnull().values.any())
print(test.isnull().sum())
pd.set_option('display.max_rows', test.shape[0]+1)
# Out:
# True
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage       45
# LotArea            0
# Street             0
# Alley            278
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         1
# MasVnrArea         1
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           7
# BsmtCond           7
# BsmtExposure       7
# BsmtFinType1       7
# BsmtFinSF1         0
# BsmtFinType2       7
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# ...

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='MSSubClass',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='MSZoning',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[18,14])
sns.countplot(x='LotFrontage',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[16,8])
sns.histplot(x='LotArea',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Street',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Alley',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='LotShape',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='LandContour',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Utilities',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='LotConfig',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='LandSlope',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Neighborhood',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Condition1',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Condition2',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='BldgType',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='HouseStyle',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='OverallQual',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# As overall quality of house increases, price is also getting increased.

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='OverallCond',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[18,12])
sns.countplot(x='YearBuilt',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[18,12])
sns.countplot(x='YearRemodAdd',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='RoofStyle',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='RoofMatl',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Exterior1st',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Exterior2nd',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='MasVnrType',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='ExterQual',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# We can see that sale price is higher for Average/Typical type of exterior material.

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='ExterCond',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Foundation',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='BsmtQual',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# We can see that, for houses whose basement height is more than 100 inches the prices are high.

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='BsmtCond',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='BsmtExposure',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='BsmtFinType1',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='BsmtFinSF1',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='BsmtUnfSF',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='BsmtFinSF2',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='TotalBsmtSF',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From above plot we observe that as basement size is increasing the price is also increased.

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='HeatingQC',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# As the heating quality and condition is excellent, the price of the house will be more.

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='CentralAir',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Electrical',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='1stFlrSF',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From above plot we observe that as first floor square feet size is increasing the price is also  increased.

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='2ndFlrSF',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='LowQualFinSF',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='GrLivArea',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the plot above we can see that there are few outliers which has high areas but low sale price.

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='BsmtFullBath',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='BsmtHalfBath',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='FullBath',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='HalfBath',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='KitchenQual',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Kitchen Quality has negative relation with SalePrice and we can see that kitchen with excellent quality are more priced.

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='TotRmsAbvGrd',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Functional',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Fireplaces',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='FireplaceQu',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='GarageType',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[18,14])
sns.countplot(x='GarageYrBlt',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='GarageFinish',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# We can see that the house with finished Garage id having more price.

# %%
plt.figure(figsize=[8,4])
sns.barplot(x='GarageCars',y='SalePrice',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From above plot we can see that house with garage having 3 cars is having more price.

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='GarageQual',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='GarageCond',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[18,12])
sns.countplot(x='GarageYrBlt',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='PavedDrive',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='WoodDeckSF',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='OpenPorchSF',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.histplot(x='EnclosedPorch',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='3SsnPorch',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[12,8])
sns.countplot(x='ScreenPorch',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='PoolArea',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='PoolQC',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='Fence',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='MiscFeature',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='MiscVal',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='MoSold',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='YrSold',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='SaleType',data=train)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.countplot(x='SaleCondition',data=train)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
# MSZoning: Identifies the general zoning classification of the sale.
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
# Alley: Type of alley access to property
#
# LotShape: General shape of property
#
# LandContour: Flatness of the property
#
# Utilities: Type of utilities available
#
#
# LotConfig: Lot configuration
#
# LandSlope: Slope of property
#
# Neighborhood: Physical locations within Ames city limits
#
# Condition1: Proximity to various conditions
#
# Condition2: Proximity to various conditions (if more than one is present)
#
# BldgType: Type of dwelling
#
# HouseStyle: Style of dwelling
#
# OverallQual: Rates the overall material and finish of the house
#
# OverallCond: Rates the overall condition of the house
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
# RoofMatl: Roof material
#
# Exterior1st: Exterior covering on house
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
# MasVnrType: Masonry veneer type
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
# Foundation: Type of foundation
#
# BsmtQual: Evaluates the height of the basement
#
# BsmtCond: Evaluates the general condition of the basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
# BsmtFinType1: Rating of basement finished area
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
# HeatingQC: Heating quality and condition
#
# CentralAir: Central air conditioning
#
# Electrical: Electrical system
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
# GarageType: Garage location
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
# GarageCond: Garage condition
#
# PavedDrive: Paved driveway
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
# Fence: Fence quality
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
# SaleCondition: Condition of sale

# %%
from scipy import stats
print(train['LotFrontage'].mean())
print('-----------')
print(train['GarageYrBlt'].mode())
print('-----------')
print(train['MasVnrType'].mode())
print('-----------')
print(train['MasVnrArea'].mode())
print('-----------')
print(train['BsmtQual'].mode())
print('-----------')
print(train['BsmtCond'].mode())
print('-----------')
print(train['BsmtExposure'].mode())
print('-----------')
print(train['BsmtFinType1'].mode())
print('-----------')
print(train['BsmtFinType2'].mode())
print('-----------')
print(train['FireplaceQu'].mode())
print('-----------')
print(train['GarageType'].mode())
print('-----------')
print(train['GarageFinish'].mode())
print('-----------')
print(train['GarageQual'].mode())
print('-----------')
print(train['GarageCond'].mode())
# Out:
# 70.98846960167715
# -----------
# 0    2006.0
# dtype: float64
# -----------
# 0    None
# dtype: object
# -----------
# 0    0.0
# dtype: float64
# -----------
# 0    TA
# dtype: object
# -----------
# 0    TA
# dtype: object
# -----------
# 0    No
# dtype: object
# -----------
# 0    Unf
# dtype: object
# -----------
# 0    Unf
# dtype: object
# -----------
# 0    Gd
# dtype: object
# -----------
# 0    Attchd
# dtype: object
# -----------
# 0    Unf
# dtype: object
# -----------
# 0    TA
# dtype: object
# -----------
# 0    TA
# dtype: object

# %%
train['LotFrontage']=train['LotFrontage'].replace(np.NaN,70.988)
train['GarageYrBlt']=train['GarageYrBlt'].replace(np.NaN,2006.0)
train['MasVnrType']=train['MasVnrType'].replace(np.NaN,'None')
train['MasVnrArea']=train['MasVnrArea'].replace(np.NaN,0.0)
train['BsmtQual']=train['BsmtQual'].replace(np.NaN,'TA')
train['BsmtCond']=train['BsmtCond'].replace(np.NaN,'TA')
train['BsmtExposure']=train['BsmtExposure'].replace(np.NaN,'No')
train['BsmtFinType1']=train['BsmtFinType1'].replace(np.NaN,'Unf')
train['BsmtFinType2']=train['BsmtFinType2'].replace(np.NaN,'Unf')
train['FireplaceQu']=train['FireplaceQu'].replace(np.NaN,'Gd')
train['GarageType']=train['GarageType'].replace(np.NaN,'Attchd')
train['GarageFinish']=train['GarageFinish'].replace(np.NaN,'Unf')
train['GarageQual']=train['GarageQual'].replace(np.NaN,'TA')
train['GarageCond']=train['GarageCond'].replace(np.NaN,'TA')
train.drop(['Id'],axis=1,inplace=True)
train.drop(['Alley'],axis=1,inplace=True)
train.drop(['PoolQC'],axis=1,inplace=True)
train.drop(['Fence'],axis=1,inplace=True)
train.drop(['MiscFeature'],axis=1,inplace=True)

#removed all null values.

# %%
print(test['LotFrontage'].mean())
print('-----------')
print(test['GarageYrBlt'].mode())
print('-----------')
print(test['MasVnrType'].mode())
print('-----------')
print(test['MasVnrArea'].mode())
print('-----------')
print(test['BsmtQual'].mode())
print('-----------')
print(test['Electrical'].mode())
print('-----------')
print(test['BsmtCond'].mode())
print('-----------')
print(test['BsmtExposure'].mode())
print('-----------')
print(test['BsmtFinType1'].mode())
print('-----------')
print(test['BsmtFinType2'].mode())
print('-----------')
print(test['FireplaceQu'].mode())
print('-----------')
print(test['GarageType'].mode())
print('-----------')
print(test['GarageFinish'].mode())
print('-----------')
print(test['GarageQual'].mode())
print('-----------')
print(test['GarageCond'].mode())
# Out:
# 66.4251012145749
# -----------
# 0    2004.0
# dtype: float64
# -----------
# 0    None
# dtype: object
# -----------
# 0    0.0
# dtype: float64
# -----------
# 0    TA
# dtype: object
# -----------
# 0    SBrkr
# dtype: object
# -----------
# 0    TA
# dtype: object
# -----------
# 0    No
# dtype: object
# -----------
# 0    GLQ
# dtype: object
# -----------
# 0    Unf
# dtype: object
# -----------
# 0    Gd
# dtype: object
# -----------
# 0    Attchd
# dtype: object
# -----------
# 0    Unf
# dtype: object
# -----------
# 0    TA
# dtype: object
# -----------
# 0    TA
# dtype: object

# %%
test['LotFrontage']=test['LotFrontage'].replace(np.NaN,70.988)
test['GarageYrBlt']=test['GarageYrBlt'].replace(np.NaN,2006.0)
test['MasVnrType']=test['MasVnrType'].replace(np.NaN,'None')
test['MasVnrArea']=test['MasVnrArea'].replace(np.NaN,0.0)
test['Electrical']=test['Electrical'].replace(np.NaN,'SBrkr')
test['BsmtQual']=test['BsmtQual'].replace(np.NaN,'TA')
test['BsmtCond']=test['BsmtCond'].replace(np.NaN,'TA')
test['BsmtExposure']=test['BsmtExposure'].replace(np.NaN,'No')
test['BsmtFinType1']=test['BsmtFinType1'].replace(np.NaN,'Unf')
test['BsmtFinType2']=test['BsmtFinType2'].replace(np.NaN,'Unf')
test['FireplaceQu']=test['FireplaceQu'].replace(np.NaN,'Gd')
test['GarageType']=test['GarageType'].replace(np.NaN,'Attchd')
test['GarageFinish']=test['GarageFinish'].replace(np.NaN,'Unf')
test['GarageQual']=test['GarageQual'].replace(np.NaN,'TA')
test['GarageCond']=test['GarageCond'].replace(np.NaN,'TA')
test.drop(['Id'],axis=1,inplace=True)
test.drop(['Alley'],axis=1,inplace=True)
test.drop(['PoolQC'],axis=1,inplace=True)
test.drop(['Fence'],axis=1,inplace=True)
test.drop(['MiscFeature'],axis=1,inplace=True)

#removed all null values.

# %%
print(train.isnull().values.any())
print(test.isnull().values.any())
# Out:
# False
# False

# %% [markdown]
# There are, indeed, a lot of NAs in our oringinal dataset, which we need to clean the dataset and fill in the NA with appropriate value to make our prediction. Then, we try to fill the NAs by using their properties according to the value in those columns.
# For the columns contain large percentage of NAs, we may remove the columns or combine them with other columns and we fill in the missing value with “none”.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


train['MSZoning']=le.fit_transform(train['MSZoning'])
train['Street']=le.fit_transform(train['Street'])
train['LotShape']=le.fit_transform(train['LotShape'])
train['LandContour']=le.fit_transform(train['LandContour'])
train['Utilities']=le.fit_transform(train['Utilities'])
train['LotConfig']=le.fit_transform(train['LotConfig'])
train['LandSlope']=le.fit_transform(train['LandSlope'])
train['Neighborhood']=le.fit_transform(train['Neighborhood'])
train['Condition1']=le.fit_transform(train['Condition1'])
train['Condition2']=le.fit_transform(train['Condition2'])
train['BldgType']=le.fit_transform(train['BldgType'])
train['HouseStyle']=le.fit_transform(train['HouseStyle'])
train['RoofStyle']=le.fit_transform(train['RoofStyle'])
train['RoofMatl']=le.fit_transform(train['RoofMatl'])
train['Exterior1st']=le.fit_transform(train['Exterior1st'])
train['Exterior2nd']=le.fit_transform(train['Exterior2nd'])
train['MasVnrType']=le.fit_transform(train['MasVnrType'])
train['ExterQual']=le.fit_transform(train['ExterQual'])
train['ExterCond']=le.fit_transform(train['ExterCond'])
train['Foundation']=le.fit_transform(train['Foundation'])
train['BsmtQual']=le.fit_transform(train['BsmtQual'])
train['BsmtCond']=le.fit_transform(train['BsmtCond'])
train['BsmtExposure']=le.fit_transform(train['BsmtExposure'])
train['BsmtFinType1']=le.fit_transform(train['BsmtFinType1'])
train['BsmtFinType2']=le.fit_transform(train['BsmtFinType2'])
train['Heating']=le.fit_transform(train['Heating'])
train['HeatingQC']=le.fit_transform(train['HeatingQC'])
train['CentralAir']=le.fit_transform(train['CentralAir'])
train['Electrical']=le.fit_transform(train['Electrical'])
train['KitchenQual']=le.fit_transform(train['KitchenQual'])
train['Functional']=le.fit_transform(train['Functional'])
train['FireplaceQu']=le.fit_transform(train['FireplaceQu'])
train['GarageType']=le.fit_transform(train['GarageType'])
train['GarageFinish']=le.fit_transform(train['GarageFinish'])
train['GarageQual']=le.fit_transform(train['GarageQual'])
train['GarageCond']=le.fit_transform(train['GarageCond'])
train['PavedDrive']=le.fit_transform(train['PavedDrive'])
train['SaleType']=le.fit_transform(train['SaleType'])
train['SaleCondition']=le.fit_transform(train['SaleCondition'])

#Converted all ordinal columns into numerical using label encoder.

# %%
test['MSZoning']=le.fit_transform(test['MSZoning'])
test['Street']=le.fit_transform(test['Street'])
test['LotShape']=le.fit_transform(test['LotShape'])
test['LandContour']=le.fit_transform(test['LandContour'])
test['Utilities']=le.fit_transform(test['Utilities'])
test['LotConfig']=le.fit_transform(test['LotConfig'])
test['LandSlope']=le.fit_transform(test['LandSlope'])
test['Neighborhood']=le.fit_transform(test['Neighborhood'])
test['Condition1']=le.fit_transform(test['Condition1'])
test['Condition2']=le.fit_transform(test['Condition2'])
test['BldgType']=le.fit_transform(test['BldgType'])
test['HouseStyle']=le.fit_transform(test['HouseStyle'])
test['RoofStyle']=le.fit_transform(test['RoofStyle'])
test['RoofMatl']=le.fit_transform(test['RoofMatl'])
test['Exterior1st']=le.fit_transform(test['Exterior1st'])
test['Exterior2nd']=le.fit_transform(test['Exterior2nd'])
test['MasVnrType']=le.fit_transform(test['MasVnrType'])
test['ExterQual']=le.fit_transform(test['ExterQual'])
test['ExterCond']=le.fit_transform(test['ExterCond'])
test['Foundation']=le.fit_transform(test['Foundation'])
test['BsmtQual']=le.fit_transform(test['BsmtQual'])
test['BsmtCond']=le.fit_transform(test['BsmtCond'])
test['BsmtExposure']=le.fit_transform(test['BsmtExposure'])
test['BsmtFinType1']=le.fit_transform(test['BsmtFinType1'])
test['BsmtFinType2']=le.fit_transform(test['BsmtFinType2'])
test['Heating']=le.fit_transform(test['Heating'])
test['HeatingQC']=le.fit_transform(test['HeatingQC'])
test['CentralAir']=le.fit_transform(test['CentralAir'])
test['Electrical']=le.fit_transform(test['Electrical'])
test['KitchenQual']=le.fit_transform(test['KitchenQual'])
test['Functional']=le.fit_transform(test['Functional'])
test['FireplaceQu']=le.fit_transform(test['FireplaceQu'])
test['GarageType']=le.fit_transform(test['GarageType'])
test['GarageFinish']=le.fit_transform(test['GarageFinish'])
test['GarageQual']=le.fit_transform(test['GarageQual'])
test['GarageCond']=le.fit_transform(test['GarageCond'])
test['PavedDrive']=le.fit_transform(test['PavedDrive'])
test['SaleType']=le.fit_transform(test['SaleType'])
test['SaleCondition']=le.fit_transform(test['SaleCondition'])

#Converted all ordinal columns into numerical using label encoder.

# %%
pd.set_option('display.max_columns', train.shape[0]+1)
train.describe()
# Out:
#         MSSubClass     MSZoning  LotFrontage        LotArea       Street  \
# count  1168.000000  1168.000000  1168.000000    1168.000000  1168.000000
# mean     56.767979     3.013699    70.988384   10484.749144     0.996575
# std      41.940650     0.633120    22.437056    8957.442311     0.058445
# min      20.000000     0.000000    21.000000    1300.000000     0.000000
# 25%      20.000000     3.000000    60.000000    7621.500000     1.000000
# 50%      50.000000     3.000000    70.988000    9522.500000     1.000000
# 75%      70.000000     3.000000    79.250000   11515.500000     1.000000
# max     190.000000     4.000000   313.000000  164660.000000     1.000000
#
#           LotShape  LandContour  Utilities    LotConfig    LandSlope  \
# count  1168.000000  1168.000000     1168.0  1168.000000  1168.000000
# mean      1.938356     2.773973        0.0     3.004281     0.064212
# std       1.412262     0.710027        0.0     1.642667     0.284088
# ...

# %% [markdown]
# We can observe that there are few outliers in some parts of dataset, but as per the information present in columns we can consider those outliers.

# %%
corr_mat = train.corr()
corr_mat
# Out:
#                MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# MSSubClass       1.000000  0.007478    -0.336681 -0.124151 -0.035981
# MSZoning         0.007478  1.000000    -0.069661 -0.023328  0.140215
# LotFrontage     -0.336681 -0.069661     1.000000  0.299451 -0.035309
# LotArea         -0.124151 -0.023328     0.299451  1.000000 -0.263973
# Street          -0.035981  0.140215    -0.035309 -0.263973  1.000000
# LotShape         0.104485  0.053655    -0.144521 -0.189201 -0.012941
# LandContour     -0.021387  0.001175    -0.073451 -0.159038  0.105226
# Utilities             NaN       NaN          NaN       NaN       NaN
# LotConfig        0.076880 -0.027246    -0.192467 -0.152063  0.000153
# LandSlope       -0.014930 -0.023952     0.046050  0.395410 -0.141572
# Neighborhood     0.013918 -0.251833     0.065824  0.010707  0.001420
# Condition1      -0.042474 -0.025651    -0.025582  0.029520  0.002189
# Condition2      -0.044319  0.031959     0.011761  0.040096  0.001406
# ...

# %%
plt.figure(figsize=[20,14])
sns.heatmap(corr_mat,annot=True)
plt.title = ('Correlation Matrix')
plt.show()

# %%
corr_target = train.corrwith(train['SalePrice'],axis=0)
corr_target.sort_values()
# Out:
# BsmtQual        -0.626850
# ExterQual       -0.624820
# KitchenQual     -0.592468
# GarageFinish    -0.537121
# HeatingQC       -0.406604
# GarageType      -0.299470
# BsmtExposure    -0.268559
# LotShape        -0.248171
# MSZoning        -0.133221
# KitchenAbvGr    -0.132108
# EnclosedPorch   -0.115004
# Heating         -0.100021
# BsmtFinType1    -0.092109
# BldgType        -0.066028
# OverallCond     -0.065642
# MSSubClass      -0.060775
# LotConfig       -0.060452
# SaleType        -0.050851
# YrSold          -0.045508
# LowQualFinSF    -0.032381
# MiscVal         -0.013071
# BsmtHalfBath    -0.011109
# BsmtFinSF2      -0.010151
# MasVnrType       0.007732
# LandSlope        0.015485
# BsmtFinType2     0.032285
# LandContour      0.032836
# Condition2       0.033956
# Street           0.044753
# BsmtCond         0.048125
# 3SsnPorch        0.060119
# MoSold           0.072764
# GarageQual       0.080795
# FireplaceQu      0.082705
# Exterior2nd      0.097541
# ...

# %%
x = train.drop('SalePrice', axis=1)
y = train['SalePrice']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(x)
scaled_data
# Out:
# array([[ 1.50830058e+00, -2.16459851e-02, -1.71023304e-05, ...,
#         -6.05487130e-01,  3.30033286e-01,  2.07931875e-01],
#        [-8.77042428e-01, -2.16459851e-02,  1.07063520e+00, ...,
#         -6.05487130e-01,  3.30033286e-01,  2.07931875e-01],
#        [ 7.70947763e-02, -2.16459851e-02,  9.36870544e-01, ...,
#         -6.05487130e-01,  3.30033286e-01,  2.07931875e-01],
#        ...,
#        [ 2.46243779e+00, -2.16459851e-02, -2.09512831e+00, ...,
#          8.99212802e-01,  3.30033286e-01,  2.07931875e-01],
#        [ 3.15629077e-01, -4.76211672e+00, -9.35834631e-01, ...,
#          1.46862836e-01,  3.30033286e-01,  2.07931875e-01],
#        [ 7.70947763e-02, -2.16459851e-02, -1.71023304e-05, ...,
#         -1.35783710e+00,  3.30033286e-01,  2.07931875e-01]])

# %%
train.cov()
# Out:
#                   MSSubClass     MSZoning    LotFrontage       LotArea  \
# MSSubClass       1759.018100     0.198554    -316.825392 -4.664118e+04
# MSZoning            0.198554     0.400840      -0.989558 -1.322948e+02
# LotFrontage      -316.825392    -0.989558     503.421485  6.018330e+04
# LotArea        -46641.184218  -132.294761   60183.299068  8.023577e+07
# Street             -0.088199     0.005188      -0.046302 -1.381954e+02
# LotShape            6.188770     0.047975      -4.579431 -2.393437e+03
# LandContour        -0.636892     0.000528      -1.170138 -1.011483e+03
# Utilities           0.000000     0.000000       0.000000  0.000000e+00
# LotConfig           5.296624    -0.028336      -7.093678 -2.237470e+03
# LandSlope          -0.177891    -0.004308       0.293528  1.006200e+03
# Neighborhood        3.508521    -0.958294       8.876688  5.764239e+02
# Condition1         -1.552856    -0.014156      -0.500338  2.305017e+02
# ...

# %%
eig_val, eig_vec = np.linalg.eig(train.cov())

# %%
print("Eigen Vectors", eig_vec)
# Out:
# Eigen Vectors [[ 3.23947612e-05 -5.43757120e-04 -1.73435555e-02 ...  1.50968948e-15
#   -6.96976390e-05  0.00000000e+00]
#  [ 1.06549610e-06  7.80574342e-07  1.41950138e-05 ...  4.65505488e-14
#    5.66264222e-02  0.00000000e+00]
#  [-9.19990518e-05  5.82081871e-04  2.83230774e-03 ... -9.68336880e-16
#   -1.82454198e-04  0.00000000e+00]
#  ...
#  [ 1.03941443e-06  3.51480804e-06 -1.40813281e-04 ... -1.29955878e-14
#   -4.56937809e-04  0.00000000e+00]
#  [-3.05832743e-06 -2.75450568e-06  2.02337337e-05 ...  9.89226177e-14
#   -8.56231833e-04  0.00000000e+00]
#  [-9.99563598e-01 -2.86658903e-02 -4.18594066e-04 ...  2.20814150e-17
#    3.05175674e-07  0.00000000e+00]]

# %%
eig_pairs = [(np.abs(eig_val[i]), eig_vec[:,i]) for i in range(len(eig_val))]

# %%
for i in eig_pairs:
    print(i[0])
# Out:
# 6263097329.575174
# 75196518.90962562
# 347553.28368607094
# 301715.19510252756
# 290477.4461153655
# 200521.0439184433
# 53112.77418841635
# 31929.724380832347
# 28432.62903720401
# 23515.597380870513
# 13869.248866528951
# 4214.635481948832
# 3496.805907691952
# 3307.346393881808
# 2831.821420401283
# 1860.6662517423963
# 1581.4556311067936
# 830.9313717599907
# 733.853135410985
# 318.6933502209134
# 207.3865092036812
# 183.70993928904284
# 33.93165518617714
# 17.40222480235469
# 7.160513990920808
# 2.8626060255693493
# 2.6153612065070737
# 2.4935901551128827
# 2.0272183365346943
# 1.9296246487790634
# 1.8574449915757256
# 1.6903037944130728
# 1.5659574373259497
# 1.4126628310328788
# 1.098564589714829
# 1.0617182332916284
# 1.0000567430324023
# 0.9291978134596225
# 0.8727757000021086
# 0.742816513046355
# 0.6888666378107824
# 0.6400882376041439
# 0.6101917286136165
# 0.5660865604522345
# 0.5212349829140758
# 0.4666192219447055
# 0.42690769172825577
# 0.38520667206526427
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(train)
scaled_data = scaler.transform(df)
scaled_data

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit_transform(scaled_data)
# Out:
# array([[-0.49620117, -1.5321365 ],
#        [ 3.11123285,  0.40231369],
#        [ 2.83698913,  0.14239518],
#        ...,
#        [-0.9155599 , -0.30645974],
#        [-6.24647145,  3.49678523],
#        [ 2.1545968 , -0.16542859]])

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.1378045  0.05504751]

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (1168, 75)

# %%
x_pca.shape
# Out:
# (1168, 2)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=train['SalePrice'])
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
train_comp = pd.DataFrame(pca.components_,columns=x.columns)
train_comp.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea    Street  LotShape  \
# 0   -0.001870 -0.075917     0.114258  0.070252  0.006403 -0.094449
# 1    0.055654  0.035394     0.078893  0.034229  0.023294  0.017382
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.018247        0.0  -0.018530  -0.008904      0.063778    0.052884
# 1    -0.060871        0.0  -0.038541  -0.031090      0.020493   -0.031603
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0    0.022474  0.011687    0.093382     0.259844    -0.068999   0.237692
# 1    0.003678 -0.124137    0.093297     0.052513     0.027813  -0.180895
#
#    YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0      0.206631   0.052769  0.026307     0.057850     0.049346   -0.015795
# 1     -0.053387  -0.000037  0.010477     0.061788     0.077400    0.010616
#
#    MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# ...

# %%
plt.figure(figsize=(16,6))
sns.heatmap(train_comp,cmap='plasma',)
# Out:
# <AxesSubplot:>

# %%
x_std = StandardScaler().fit_transform(train)
pca = PCA().fit(x_std)
plt.plot(np.cumsum(pca.explained_variance_ratio_),'ro-')
plt.xlabel('no. of components')
plt.ylabel('var explained')
plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(x_pca,y,test_size=0.25, random_state=15)

# %%
from sklearn.linear_model import (Ridge, Lasso)
lasso = Lasso(alpha=0.2, normalize=True)
lasso.fit(x_pca,y)
lasso_coef = lasso.coef_
print(lasso_coef)
# Out:
# [21098.98779146  4370.65656984]

# %%
colnames = x.columns
plt.figure(figsize=[18,8])
plt.plot(range(len(colnames)), lasso_coef)
plt.xticks(range(len(colnames)), colnames.values, rotation=60) 
plt.margins(0.02)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
print('R^2:',metrics.r2_score(y_test, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-x_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2: 0.7096823688392628
# Adjusted R^2: 0.7076732502845173
# MAE: 26849.952438791308
# MSE: 1651336577.9951224
# RMSE: 40636.64083059921

# %% [markdown]
# 𝑅^2 : It is a measure of the linear relationship between X and Y. It is interpreted as the proportion of the variance in the dependent variable that is predictable from the independent variable.
#
# Adjusted 𝑅^2 :The adjusted R-squared compares the explanatory power of regression models that contain different numbers of predictors.
#
# MAE : It is the mean of the absolute value of the errors. It measures the difference between two continuous variables, here actual and predicted values of y.
#
# MSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.
#
# RMSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.

# %%
from sklearn.linear_model import LinearRegression

reg_test = LinearRegression()
reg_test.fit(x_test,y_test)
y_test_pred = reg_test.predict(x_test)
print('R^2:', metrics.r2_score(y_test, y_test_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.7174665831120369
# Adjusted R^2: 0.7155113345522586
# MAE: 25918.05183379488
# MSE: 1607059701.9811175
# RMSE: 40088.14914636391

# %%
from sklearn.ensemble import RandomForestRegressor

RFR = RandomForestRegressor(n_estimators=10,random_state = 0 )
RFR.fit(x_train, y_train)
y_pred=RFR.predict(x_test)
print('R^2:',metrics.r2_score(y_test, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-x_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2: 0.6255195052597082
# Adjusted R^2: 0.6229279447424744
# MAE: 24886.59109589041
# MSE: 2130057813.7053423
# RMSE: 46152.54937384654

# %%
from sklearn.ensemble import RandomForestRegressor

RFR_test = RandomForestRegressor(n_estimators=10,random_state = 0 )
RFR_test.fit(x_test, y_test)
y_test_pred=RFR_test.predict(x_test)
print('R^2:', metrics.r2_score(y_test, y_test_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.9575351413311959
# Adjusted R^2: 0.9572412668767405
# MAE: 10129.47397260274
# MSE: 241541563.00746578
# RMSE: 15541.60747823293

# %%
from sklearn.neighbors import KNeighborsRegressor

KNR = KNeighborsRegressor()
KNR.fit(x_train, y_train)
y_pred=KNR.predict(x_test)
print('R^2:',metrics.r2_score(y_test, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-x_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2: 0.6782201558121592
# Adjusted R^2: 0.6759933056793714
# MAE: 23694.007534246575
# MSE: 1830294717.700959
# RMSE: 42781.94382798611

# %%
from sklearn.neighbors import KNeighborsRegressor

KNR_test = KNeighborsRegressor()
KNR_test.fit(x_test, y_test)
y_test_pred=KNR_test.predict(x_test)
print('R^2:', metrics.r2_score(y_test, y_test_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.8136150982908408
# Adjusted R^2: 0.8123252373793587
# MAE: 19981.439041095888
# MSE: 1060163671.588904
# RMSE: 32560.154661624445

# %%
from sklearn.tree import DecisionTreeRegressor
RTD = DecisionTreeRegressor(random_state = 0)
RTD.fit(x_train, y_train)
y_pred = RTD.predict(x_test)
print('R^2:',metrics.r2_score(y_test, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-x_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2: 0.4934259835996291
# Adjusted R^2: 0.48992028106398633
# MAE: 31710.719178082192
# MSE: 2881410265.712329
# RMSE: 53678.769226877106

# %%
from sklearn.tree import DecisionTreeRegressor
RTD_test = DecisionTreeRegressor(random_state = 0)
RTD_test.fit(x_test, y_test)
y_test_pred = RTD_test.predict(x_test)
print('R^2:', metrics.r2_score(y_test, y_test_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 1.0
# Adjusted R^2: 1.0
# MAE: 0.0
# MSE: 0.0
# RMSE: 0.0

# %%
scr=cross_val_score(reg, x_pca, y, cv=5)
print('Cross validation score of Linear Regression : ',scr.mean())

scr=cross_val_score(RFR, x_pca, y, cv=5)
print('Cross validation score of RFR : ',scr.mean())

scr=cross_val_score(KNR, x_pca, y, cv=5)
print('Cross validation score of KNR : ',scr.mean())

scr=cross_val_score(RTD, x_pca, y, cv=5)
print('Cross validation score of SVR : ',scr.mean())
# Out:
# Cross validation score of Linear Regression :  0.7322342198781245
# Cross validation score of RFR :  0.7827006462384858
# Cross validation score of KNR :  0.7800649449256765
# Cross validation score of SVR :  0.7088039586526416

# %%
scr=cross_val_score(reg_test, x_pca, y, cv=5)
print('Cross validation score of Linear Regression : ',scr.mean())

scr=cross_val_score(RFR_test, x_pca, y, cv=5)
print('Cross validation score of RFR : ',scr.mean())

scr=cross_val_score(KNR_test, x_pca, y, cv=5)
print('Cross validation score of KNR : ',scr.mean())

scr=cross_val_score(RTD_test, x_pca, y, cv=5)
print('Cross validation score of RTD : ',scr.mean())
# Out:
# Cross validation score of Linear Regression :  0.7322342198781245
# Cross validation score of RFR :  0.7827006462384858
# Cross validation score of KNR :  0.7800649449256765
# Cross validation score of RTD :  0.7088039586526416

# %% [markdown]
# Linear Regression Model is having least difference between cross validation score and r2 score in both train and test data, so we can choose Linear Regression as best model with r2 score of 70.96% for train data.

# %%
import joblib
joblib.dump(reg,'House_Price.pkl')
# Out:
# ['House_Price.pkl']
